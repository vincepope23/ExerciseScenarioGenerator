# %%
import importlib
from scenariogenerator.backend import user_actions

importlib.reload(user_actions)
from scenariogenerator.backend.user_actions import get_prompt, get_gefahr_options, generate_szenario

# %%
gefahr_options = get_gefahr_options()
gefahr_options
# Out:
# ['Chemischer Anschlag',
#  'Erdölmangellage',
#  'Hagelschlag',
#  'Starker Schneefall',
#  'Starkregen']

# %%
gefahr = gefahr_options[0]
gefahr
# Out:
# 'Chemischer Anschlag'

# %%
! ls
# Out:
#  activate_env.sh       prompts		  scenariogenerator
# 'Backend test.ipynb'   pyproject.toml	  scenariogenerator.egg-info
#  data		       requirements.txt
#  Mistral_v3.ipynb      run_notebook.sh

# %%
prompt = get_prompt(gefahr)
prompt[:100]
# Out:
# dict_keys(['gefahr', 'gefahr_phasen', 'gefahr_schwerestufen', 'gefahr_einflussfaktoren', 'gefahr_auswirkungen', 'userinput_text'])
# Du bist ein Experte für Notfallplanung und Risikobeurteilung.
#
# Stütze dich ausschliesslich auf die bereitgestellten Dokumente. Ergänze keine Informationen aus eigenem Wissen.
#
# ---
#
# Erstelle ein Übungsszenario zur folgenden Gefahr: {gefahr}
#
# Verwende dabei diese Dokumentquellen:
# ---
# - Phasen:
# {gefahr_phasen}
#
# ---
# - Schwerestufen:
# {gefahr_schwerestufen} → Stufe 2 «gross»
#
# ---
# - Auswirkungen:
# {gefahr_auswirkungen}
#
# ---
# - Einflussfaktoren:
# {gefahr_einflussfaktoren}
#
# ---
# Beachte ausserdem folgende Userinput: {userinput_text}
#
# ---
#
# Das Szenario beschreibt ausschliesslich den Tatsachenverlauf – so, als würde niemand eingreifen.
#
# Enthalten sein muss:
# - Alle Phasen in zeitlicher Reihenfolge gemäss {gefahr_phasen}
# - Die charakteristischen Merkmale jeder Phase
#
# Nicht enthalten sein darf:
# - Ziele oder Handlungsempfehlungen
# - Reaktionen, Massnahmen oder Eingriffe
# - Mittelbare oder langfristige Folgen nach der Nachphase
#
# ---
#
# Ausgabeformat (Markdown):
#
# ## Szenario: [Titel]
# **Gefahr:** [Gefahrentyp]
# **Schwerestufe:** 2 – gross
#
# ---
#
# ### Phase 1: [Phasenname]
# [Merkmale dieser Phase]
#
# ### Phase 2: [Phasenname]
# [Merkmale dieser Phase]
#
# ...
# 'Du bist ein Experte für Notfallplanung und Risikobeurteilung.\n\nStütze dich ausschliesslich auf die b'

# %%
import os
os.chdir("scenariogenerator")

# %%
prompt = get_prompt(gefahr)
prompt[:100]
# Out:
# dict_keys(['gefahr', 'gefahr_phasen', 'gefahr_schwerestufen', 'gefahr_einflussfaktoren', 'gefahr_auswirkungen', 'userinput_text'])
# Du bist ein Experte für Notfallplanung und Risikobeurteilung.
#
# Stütze dich ausschliesslich auf die bereitgestellten Dokumente. Ergänze keine Informationen aus eigenem Wissen.
#
# ---
#
# Erstelle ein Übungsszenario zur folgenden Gefahr: {gefahr}
#
# Verwende dabei diese Dokumentquellen:
# ---
# - Phasen:
# {gefahr_phasen}
#
# ---
# - Schwerestufen:
# {gefahr_schwerestufen} → Stufe 2 «gross»
#
# ---
# - Auswirkungen:
# {gefahr_auswirkungen}
#
# ---
# - Einflussfaktoren:
# {gefahr_einflussfaktoren}
#
# ---
# Beachte ausserdem folgende Userinput: {userinput_text}
#
# ---
#
# Das Szenario beschreibt ausschliesslich den Tatsachenverlauf – so, als würde niemand eingreifen.
#
# Enthalten sein muss:
# - Alle Phasen in zeitlicher Reihenfolge gemäss {gefahr_phasen}
# - Die charakteristischen Merkmale jeder Phase
#
# Nicht enthalten sein darf:
# - Ziele oder Handlungsempfehlungen
# - Reaktionen, Massnahmen oder Eingriffe
# - Mittelbare oder langfristige Folgen nach der Nachphase
#
# ---
#
# Ausgabeformat (Markdown):
#
# ## Szenario: [Titel]
# **Gefahr:** [Gefahrentyp]
# **Schwerestufe:** 2 – gross
#
# ---
#
# ### Phase 1: [Phasenname]
# [Merkmale dieser Phase]
#
# ### Phase 2: [Phasenname]
# [Merkmale dieser Phase]
#
# ...
# 'Du bist ein Experte für Notfallplanung und Risikobeurteilung.\n\nStütze dich ausschliesslich auf die b'

# %%
import os
os.chdir("frontend")

# %%
prompt = get_prompt(gefahr)
prompt[:100]
# Out:
# dict_keys(['gefahr', 'gefahr_phasen', 'gefahr_schwerestufen', 'gefahr_einflussfaktoren', 'gefahr_auswirkungen', 'userinput_text'])
# Du bist ein Experte für Notfallplanung und Risikobeurteilung.
#
# Stütze dich ausschliesslich auf die bereitgestellten Dokumente. Ergänze keine Informationen aus eigenem Wissen.
#
# ---
#
# Erstelle ein Übungsszenario zur folgenden Gefahr: {gefahr}
#
# Verwende dabei diese Dokumentquellen:
# ---
# - Phasen:
# {gefahr_phasen}
#
# ---
# - Schwerestufen:
# {gefahr_schwerestufen} → Stufe 2 «gross»
#
# ---
# - Auswirkungen:
# {gefahr_auswirkungen}
#
# ---
# - Einflussfaktoren:
# {gefahr_einflussfaktoren}
#
# ---
# Beachte ausserdem folgende Userinput: {userinput_text}
#
# ---
#
# Das Szenario beschreibt ausschliesslich den Tatsachenverlauf – so, als würde niemand eingreifen.
#
# Enthalten sein muss:
# - Alle Phasen in zeitlicher Reihenfolge gemäss {gefahr_phasen}
# - Die charakteristischen Merkmale jeder Phase
#
# Nicht enthalten sein darf:
# - Ziele oder Handlungsempfehlungen
# - Reaktionen, Massnahmen oder Eingriffe
# - Mittelbare oder langfristige Folgen nach der Nachphase
#
# ---
#
# Ausgabeformat (Markdown):
#
# ## Szenario: [Titel]
# **Gefahr:** [Gefahrentyp]
# **Schwerestufe:** 2 – gross
#
# ---
#
# ### Phase 1: [Phasenname]
# [Merkmale dieser Phase]
#
# ### Phase 2: [Phasenname]
# [Merkmale dieser Phase]
#
# ...
# 'Du bist ein Experte für Notfallplanung und Risikobeurteilung.\n\nStütze dich ausschliesslich auf die b'

# %%
from dotenv import load_dotenv
import os
load_dotenv()
api_token =  os.getenv("MISTRAL_API_KEY") 
assert api_token is not None

szenario = generate_szenario(prompt, "mistral")

# %%
print(szenario)
# Out:
# ## Szenario: Chemischer Anschlag mit Sarin in einer Flughafen-Abflughalle
# **Gefahr:** Chemischer Anschlag mit C-Kampfstoff (Sarin)
# **Schwerestufe:** 2 – gross
#
# ---
#
# ### Phase 1: Vorphase (Ausgangslage)
# - In der voll besetzten Abflughalle eines großen Flughafens (ca. 200 Personen) wird **1 Liter flüssiges Sarin** auf den Boden ausgeschüttet.
# - Es bildet sich eine **nahezu farb- und geruchlose Lache** von etwa 1 m² Fläche, aus der das Nervengift langsam verdunstet.
# - Die Verdunstung beginnt unmittelbar, ohne dass Anwesende die Gefahr erkennen.
# - Die Lache bleibt zunächst unbemerkt, da Sarin optisch und olfaktorisch nicht wahrnehmbar ist.
#
# ---
#
# ### Phase 2: Hauptphase – Tiefere Eskalationsstufe (Frühe Ereignisphase)
# - **Ausbreitung der Sarin-Dämpfe**: Innerhalb weniger Minuten verdunstet das flüssige Sarin und breitet sich als gasförmiger Kampfstoff in der Abflughalle aus.
# - **Erste Symptome**: Bei exponierten Personen treten nach **Sekunden bis Minuten** erste Vergiftungserscheinungen auf:
#   - Leichte Symptome: Atembeschwerden, Zittern, vermehrter Speichelfluss, Miosis (Pupillenverengung).
#   - Mittelschwere Symptome: Übelkeit, Erbrechen, Muskelkrämpfe, Schwäche.
# - **Panikreaktionen**: Betroffene bemerken die Symptome, erkennen jedoch nicht die Ursache. Einzelne Personen brechen zusammen, was zu **unkontrollierten Fluchtbewegungen** führt.
# - **Verschleppung des Kampfstoffs**: Flüchtende Personen tragen das Gift durch kontaminierte Schuhe oder Kleidung in angrenzende Bereiche (z. B. Check-in-Schalter, Wartezonen).
# - **Ausbreitung über Lüftungsanlagen**: Die Dämpfe werden teilweise über die Klimaanlage in benachbarte Gebäudeteile verteilt.
# - **Erste Todesfälle**: Nach **5–10 Minuten** sterben die ersten Personen an Atemlähmung oder Krämpfen.
#
# ---
#
# ### Phase 3: Hauptphase – Höhere Eskalationsstufe (Späte Ereignisphase)
# - **Massive Ausweitung der Symptome**: Die Zahl der Betroffenen steigt rapide an. Schwere Vergiftungen (Bewusstlosigkeit, Krämpfe, Atemstillstand) häufen sich.
# - **Kollaps der Infrastruktur**: Die Abflughalle ist überfüllt mit panischen Personen, die versuchen zu fliehen. Fluchtwege sind blockiert, was zu weiteren Verletzungen führt.
# - **Ausbreitung über den gesamten Flughafen**:
#   - Durch Fluchtbewegungen und Lüftungssysteme erreicht das Sarin angrenzende Bereiche (z. B. Einkaufszonen, Gates, Gepäckausgabe).
#   - Kontaminierte Personen verbreiten das Gift in bisher unbetroffene Zonen.
# - **Höhepunkt der Todesfälle**: Innerhalb von **30–60 Minuten** sterben **10–20 Personen** (5–10 % der Betroffenen). Weitere **~100 Personen** erleiden leichte bis schwere Vergiftungen.
# - **Zusammenbruch der Kommunikation**: Betroffene und Augenzeugen verbreiten über soziale Medien unbestätigte Meldungen, was zu **Desinformation und zusätzlicher Panik** führt.
# - **Überlastung der Notrufnummern**: Die Leitstellen sind mit Anrufen überlastet, was die Koordination der Rettungskräfte verzögert.
#
# ---
#
# ### Phase 4: Nachphase (Regenerations- und Ermittlungsphase)
# - **Dekontamination des Gebäudes**:
#   - Der betroffene Gebäudeflügel und angrenzende Bereiche werden **abgeriegelt und geschlossen**.
#   - Die Reinigung der kontaminierten Flächen beginnt, dauert jedoch **mehrere Tage bis Wochen**, abhängig von Material und Kontaminationsgrad.
# - **Ermittlungen**:
#   - Die Bundesanwaltschaft leitet forensische Untersuchungen ein, um den Tathergang zu rekonstruieren.
#   - Die Ermittlungen dauern **Wochen bis Monate** und umfassen die Auswertung von Überwachungskameras, Zeugenaussagen und chemischen Analysen.
# - **Eingeschränkter Betrieb**:
#   - Der Flugverkehr bleibt **für mehrere Tage vollständig eingestellt**.
#   - Nach Wiedereröffnung wird der Betrieb zunächst **stark reduziert** fortgeführt (z. B. nur Inlandsflüge, eingeschränkte Passagierzahlen).
# - **Langfristige Folgen (innerhalb der Nachphase)**:
#   - **Wirtschaftliche Einbußen**: Der Flughafen verzeichnet **Stornierungen von Reisen** und einen **Rückgang von Flugbuchungen** über mehrere Monate.
#   - **Psychische Belastung**: Betroffene, Angehörige und Einsatzkräfte leiden unter **posttraumatischen Belastungsstörungen (PTSD)** und benötigen psychologische Unterstützung.
#   - **Internationale Aufmerksamkeit**: Negative Berichterstattung über **Sicherheitslücken** führt zu einem **Vertrauensverlust in Behörden** und einem **Rückgang des Tourismus**.
