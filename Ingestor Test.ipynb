# %%
from scenariogenerator.ingest.ingest_scenarios import ScenarioIngestor

# %%
ing = ScenarioIngestor()

# %%
ing.ingest_all()
# Out:
# Start ingesting scenarios
# /home/melanie/miniconda3/Desktop/Projects/ExerciseScenarioGenerator/data/Gefährdungsszenarien/02-Starkregen-GD-de.md
# Analyze response: 4678
# JSON response: 5076
# Starkregen
# 100%|██████████████████████████████████████████| 9/9 [00:00<00:00, 29630.09it/s]
# # Gefährdungsszenarien
#
# - [Starkregen](Starkregen_index.md)
#
# /home/melanie/miniconda3/Desktop/Projects/ExerciseScenarioGenerator/data/Gefährdungsszenarien/12-Erdbeben-GD-de.md
# Analyze response: 5410
# JSON response: 5872
# Erdbeben
# 100%|██████████████████████████████████████████| 9/9 [00:00<00:00, 26602.35it/s]
# # Gefährdungsszenarien
#
# - [Starkregen](Starkregen_index.md)
# - [Erdbeben](Erdbeben_index.md)
#
# /home/melanie/miniconda3/Desktop/Projects/ExerciseScenarioGenerator/data/Gefährdungsszenarien/38-Anschlag-C-Kampfstoff-GD-de.md
# Analyze response: 7651
# JSON response: 8184
# Chemischer_Anschlag
# 100%|██████████████████████████████████████████| 9/9 [00:00<00:00, 29935.56it/s]
# ...
