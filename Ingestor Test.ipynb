# %%
from scenariogenerator.ingest.ingest_scenarios import ScenarioIngestor

# %%
ing = ScenarioIngestor()

# %%
ing.ingest_all()
# Out:
# Start ingesting scenarios
#   0%|                                                    | 0/44 [00:00<?, ?it/s]
# /home/melanie/miniconda3/Desktop/Projects/ExerciseScenarioGenerator/data/Gefährdungsszenarien/19-Gefahrengutunfall-Strasse-GD-de.md
# Analyze response: 5197
#   2%|█                                           | 1/44 [01:03<45:17, 63.20s/it]
# JSON response: 5637
# Gefahrgutunfall
# /home/melanie/miniconda3/Desktop/Projects/ExerciseScenarioGenerator/data/Gefährdungsszenarien/06-Hitzewelle-GD-de.md
# Analyze response: 5961
#   5%|██                                          | 2/44 [02:15<47:58, 68.54s/it]
# JSON response: 6424
# Hitzewelle
# /home/melanie/miniconda3/Desktop/Projects/ExerciseScenarioGenerator/data/Gefährdungsszenarien/13-Vulkanausbruch-Ausland-GD-de.md
# Analyze response: 4751
#   7%|███                                         | 3/44 [03:02<40:10, 58.80s/it]
# JSON response: 5102
# Vulkanausbruch
# ...
